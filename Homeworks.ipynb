# %% [markdown]
# Bài 1

# %%
n=int(input("Nhập số nguyên n"))
print(2*n)
# Out:
# 10

# %% [markdown]
# Bài 2

# %%
while True:
      a,b=map(float,input("Nhập chiều rộng và chiều dài hình chữ nhật theo thứ tự ").split())
      if b>=a :
        s=(a*b-3.14*(a/2)**2)
        print(f"Diện tích còn để trồng cây là:{s:.2f}")

        break
      else:
         print("Nhập sai!Chiều dài phải lớn hơn chiều rộng.Vui lòng nhập lại ")
# Out:
# Diện tích còn để trồng cây là:10.93

# %% [markdown]
# Bài 3

# %%
a=input("Nhập một kí tự chữ cái bất kì")
b=ord(a)
if b<96 :
    print(chr(b+32))
else:
    print(chr(b-32))
# Out:
# z

# %% [markdown]
# Bài 4

# %%
a=input("Nhập một kí tự chữ cái bất kì")
b=ord(a)
if 64<b<91 or 96<b<121:
    print(a," là kí tự alphabet")
else:
    print(a," không là kí tự alphabet")
# Out:
# E  là kí tự alphabet

# %% [markdown]
# Bài 5

# %%
a=input("Nhập một kí tự chữ cái in hoa bất kì")
b=ord(a)
if b != 65:
    print(chr(b+31))
else:
    print("Trường hợp đặc biệt")
# Out:
# a

# %% [markdown]
# Bài 6

# %%
a,b,c=map(int,input("Nhập lần lượt 3 cạnh của tam giác ").split())
if a<b+c and b<a+c and c<a+b:
    print("Đây là 3 cạnh của tam giác")
else:
    print("Đây không là 3 cạnh của tam giác")
# Out:
# Đây là 3 cạnh của tam giác

# %% [markdown]
# Bài 7

# %%
a= input("Nhập vào một chuỗi lớn hơn hoặc bằng 20 kí tự")
if len(a) >= 20:    
    print("Ký tự thứ năm là:", a[4])
    print("Ký tự thứ chín là:", a[8])
else:
    print(f"Lỗi: Chuỗi '{a}' quá ngắn! Yêu cầu >= 20 ký tự.")
# Out:
# Ký tự thứ năm là: c
# Ký tự thứ chín là: o

# %% [markdown]
# Bài 8

# %%
a=input("Nhập tên chủ hộ")
b=int(input("Nhập chỉ số điện tháng trước:"))
c=int(input("Nhập chỉ số điện tháng này:"))
sodien=c-b
print("Họ và tên :",a)
if sodien<=50:
    print("Tiền điện phải trả là :",sodien*1984+sodien*1984*8/100)
elif 51<=sodien<=100 :

    print("Tiền điện phải trả là :",((sodien-50)*2050+50*1984)+((sodien-50)*2050+50*1984)*8/100)
elif 101<=sodien<=200 :

    print("Tiền điện phải trả là :",((sodien-100)*2380+50*1984+50*2050)+((sodien-100)*2380+50*1984+50*2050)*8/100)
elif 201<=sodien<=300 :

    print("Tiền điện phải trả là :",((sodien-200)*2998+50*(1984+2050)+100*2380)+((sodien-200)*2998+50*(1984+2050)+100*2380)*8/100)
elif 301<=sodien<=400 :

    print("Tiền điện phải trả là :",((sodien-300)*3350+50*(1984+2050)+100*(2380+2998))+((sodien-300)*3350+50*(1984+2050)+100*(2380+2998))*8/100)
else:

    print("Tiền điện phải trả là :",((sodien-400)*3460+50*(1984+2050)+100*(2380+2998+3350))+((sodien-400)*3460+50*(1984+2050)+100*(2380+2998+3350))*8/100)
# Out:
# Họ và tên : Đỗ Đào nguyên
# Tiền điện phải trả là : 1855504.8
