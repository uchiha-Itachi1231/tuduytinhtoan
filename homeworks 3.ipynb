# %% [markdown]
# W3A2

# %%
a=int(input("Nhập số a"))
b=int(input("Nhập số b"))
print("Gía trị ban đầu : a= ",a,"b=",b)
a=a^b
b=a^b
a=a^b
print("Giá trị sau khi hoán đổi :")
print("a=",a)
print("b=",b)
# Out:
# Gía trị ban đầu : a=  1 b= 2
# Giá trị sau khi hoán đổi :
# a= 2
# b= 1

# %% [markdown]
# W3A3

# %%
a=int(input("Nhập 1 số bất kì để kiểm tra xem đó có phải là lũy thừa của 2 hay không"))
if a & (a-1) ==0 :
    print("Số ",a," là lũy thừa của 2")
else:
    print("Số ",a," không phải lũy thừa của 2")
# Out:
# Số  16  là lũy thừa của 2

# %% [markdown]
# W3A4 và W3A5

# %%
m=float(input("Nhập số m"))
n=float(input("Nhập số n"))
if m%n !=0 :
    c=m//n
    d=(m//n)+1
    print("số sau chia là",m/n,"làm tròn lên là",d,"làm tròn xuống là",c)
    if( m/n - m//n )>0.5 :
        print("số nguyên gần nhất là :",(m//n)+1)
    elif (m/n - m//n )<0.5 :
        print("số nguyên gần nhất là :",m//n)
    else:
        print("Số nguyên gần nhất là ",m//n,"hoặc",(m//n)+1)
else:
    print ("kết quả sau chia là :",m/n,"đây là số nguyên nên không được làm tròn")
# Out:
# số sau chia là 0.8333333333333334 làm tròn lên là 1.0 làm tròn xuống là 0.0
# số nguyên gần nhất là : 1.0

# %% [markdown]
# W3A6

# %%
x=int(input("Nhập vào một số nguyên dương bất kì"))
while x<0 :
    print("Nhập sai! Hãy nhập lại cho đúng")
    x=int(input("Nhập vào một số nguyên dương bất kì"))
        
else:
    if x%2==0:
        print ("số đó là số chẵn")
    else:
        print("Số đó là số lẻ")
# Out:
# Nhập sai! Hãy nhập lại cho đúng
# Nhập sai! Hãy nhập lại cho đúng
# Nhập sai! Hãy nhập lại cho đúng
# số đó là số chẵn

# %% [markdown]
# W3A7

# %%
a,b=map(int,input("Nhập 2 số nguyên a,b").split())
if (a and b)<0 :
    print("True")
else:
    print("False")
# Out:
# False

# %% [markdown]
# W3A9

# %%
a,b,c=map(int,input("Nhập vào 3 số nguyên dương để kiểm tra xem có là độ dài cạnh của 1 tam giác được không").split())
if a+b>c and a+c> b and b+c>a :
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# W3A8
