# %%
#W1A1
print("Hello World")
# Out:
# Hello World

# %%
#W1A2
a=input("Hãy nhập tên của bạn")
print("Chào ",a,"đến với lớp tư duy tính toán AE2")

# %%
#W1A3
a=int(input("Nhập số a"))
b=int(input("Nhập số b"))
print("a+b=",a+b)
# Out:
# a+b= 5
