# %% [markdown]
# W2A1

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# W2A2

# %%
a=input("Hãy nhập tên của bạn")
print("Chào",a,"rất vui được gặp bạn" )
# Out:
# Chào  rất vui được gặp bạn

# %% [markdown]
# W2A3

# %%
a=int(input("Nhập số a"))
b=int(input("Nhập số b"))
print("a+b=",a+b)
# Out:
# a+b= 5

# %% [markdown]
# W2A4

# %%
a1,b1,c1,a2,b2,a3=map(int,input("Hãy nhập các đầu điểm theo thứ tự : a1,b1,c1,a2,b2,a3").split())
print("Điểm trung bình của 6 môn học là :",(a1+b1+c1+2*a2+2*b2+3*a3)/10)
# Out:
# Điểm trung bình của 6 môn học là : 9.6

# %% [markdown]
# W2A5

# %%
a,b=map(int,input("Nhập lần lượt 2 số a,b theo thứ tự ").split())
print(" a mũ b=",a**b)
# Out:
#  a mũ b= 8

# %% [markdown]
# W2A6

# %%
a= input("nhập một kí tự chữ cái bất kì ")
b= ord(a)
print(chr(b-32))
# Out:
# A

# %% [markdown]
# W2A7

# %%
print("A =((13^2) x 3) + 5 = ",((13 ** 2) * 3) + 5," và B =13^2 x 3 + 5 =",13**2*3 + 5 )
# Out:
# A =((13^2) x 3) + 5 =  512  và B =13^2 x 3 + 5 = 512

# %% [markdown]
# W2A8

# %%
a= int(input("Hãy nhập nhiệt độ celcius:"))
b=9/5*a+32
print("Quy đổi ",a,"độ C = ",round(b,2),"độ F" )
# Out:
# Quy đổi  66 độ C =  150.8 độ F

# %% [markdown]
# W2A9

# %%
x = int(input("Nhập số tiền đồng hồ mà Đạt mua"))
print("Số tiền Đạt phải trả là :",x + 10 +x*40/100,"USD" )
# Out:
# Số tiền Đạt phải trả là : 24.0 USD

# %% [markdown]
# W2A10

# %%
a,b,c=input("Nhập tên 3 người bất kì theo thứ tự").split() 
print("Hi ",c,",",b,"and",a)
# Out:
# Hi  Tom , Nolan and David

# %% [markdown]
# W2A11

# %%
a,b=map(int,input("Hãy nhập số giờ và số phút theo thứ tự").split())
print("Số giây là :",a*3600+b*60)
# Out:
# Số giây là : 5400

# %% [markdown]
# W2A12

# %%
a=int(input("Nhập độ dài cạnh của Rubik:"))
print("Cần số miếng dán là :",a**2*6)
# Out:
# Cần số miếng dán là : 54

# %% [markdown]
# W2A13

# %%
a,b= map(int,input("Nhập số a và b theo thứ tự").split())
c=a*b
print("Hàng đơn vị của phép tính a x b là :",c%10)
# Out:
# Hàng đơn vị của phép tính a x b là : 4

# %% [markdown]
# W2A14

# %%
a,b=map(int,input("Nhập số a và b theo thứ tự").split())
a,b=b,a
print("số a,b khi hoán đổi =",a,b)
# Out:
# số a,b khi hoán đổi = 2 1

# %% [markdown]
# W2A15
